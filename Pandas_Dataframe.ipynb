# %% [markdown]
# Create DataFrame

# %%
import pandas as pd

# %%
pd.DataFrame([10,20,30])
# Out:
#     0
# 0  10
# 1  20
# 2  30

# %% [markdown]
# pd.DataFrame(data,index,columns,dtype)

# %% [markdown]
# ## pd.DataFrame(data,index,columns,dtype)

# %%
import numpy as np  
a= np.random.random((4,4))
a
# Out:
# array([[0.18127785, 0.66981329, 0.76603208, 0.79292558],
#        [0.73734114, 0.88779596, 0.93863958, 0.68883821],
#        [0.93738358, 0.11235812, 0.03230102, 0.05256714],
#        [0.49371345, 0.88252435, 0.07857269, 0.92389851]])

# %%
pd.DataFrame(a)
# Out:
#           0         1         2         3
# 0  0.181278  0.669813  0.766032  0.792926
# 1  0.737341  0.887796  0.938640  0.688838
# 2  0.937384  0.112358  0.032301  0.052567
# 3  0.493713  0.882524  0.078573  0.923899

# %%
#If we want to change columns header then
df1 = pd.DataFrame(a,columns=['a','b','c','d'])
df1
# Out:
#           a         b         c         d
# 0  0.181278  0.669813  0.766032  0.792926
# 1  0.737341  0.887796  0.938640  0.688838
# 2  0.937384  0.112358  0.032301  0.052567
# 3  0.493713  0.882524  0.078573  0.923899

# %%
#How to replace perticular column name
df1.columns = df1.columns.str.replace('c','e')
df1
# Out:
#           a         b         e         d
# 0  0.181278  0.669813  0.766032  0.792926
# 1  0.737341  0.887796  0.938640  0.688838
# 2  0.937384  0.112358  0.032301  0.052567
# 3  0.493713  0.882524  0.078573  0.923899

# %%
# we can also create a df using dict with multiple values
emp = { 'name':['Prajakta','Gauri','Anil'],
        'emp' :[101,202,303],
        'profile':['Data Scientist','Developer','CEO']   

}
emp
# Out:
# {'name': ['Prajakta', 'Gauri', 'Anil'],
#  'emp': [101, 202, 303],
#  'profile': ['Data Scientist', 'Developer', 'CEO']}

# %%
# Above dict is created now create DF
#Supply Dict to dataframe
pd.DataFrame(emp)
# Out:
#        name  emp         profile
# 0  Prajakta  101  Data Scientist
# 1     Gauri  202       Developer
# 2      Anil  303             CEO

# %% [markdown]
# ## Lets check properties of DataFrame

# %%
df1
# Out:
#           a         b         e         d
# 0  0.181278  0.669813  0.766032  0.792926
# 1  0.737341  0.887796  0.938640  0.688838
# 2  0.937384  0.112358  0.032301  0.052567
# 3  0.493713  0.882524  0.078573  0.923899

# %%
# num. of rows and columns
# check total number of records
df1.shape
# Out:
# (4, 4)

# %%
# check column names
df1.columns
# Out:
# Index(['a', 'b', 'e', 'd'], dtype='object')

# %%
# check index
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# size: gives total elements present
# df is 2D
df1.size
# Out:
# 16

# %%
# Count(): Method gives total elements present in each column
# df is 2D
df1.count()
# Out:
# a    4
# b    4
# e    4
# d    4
# dtype: int64

# %%
# if they ask number of rows
df1.shape
df1.shape[0]
# Out:
# 4

# %%
df1.shape[1] #No of clolumns
# Out:
# 4

# %%
len(df1) #It count rows
# Out:
# 4
